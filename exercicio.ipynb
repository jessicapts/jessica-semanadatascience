# %% [markdown]
# # Importando os arquivos

# %%
import pandas as pd

# %% [markdown]
# # Exportando dataset

# %%
url = "dataset/parfum.csv"
pd.read_csv(url)
# Out:
#                   brand                                              title  \
# 0      Carolina Herrera  Good Girl by Carolina Herrera 2.7 oz Eau De Pa...
# 1              As Shown  Parfums de Marly Delina La Rosee Eau de Parfum...
# 2                 PRADA  PRADA Paradoxe by Prada EDP 3.0oz/90ml Spray P...
# 3               As Show  J'adore Parfum D'eau by Christian 3.4 oz EDP F...
# 4               Khadlaj  Shiyaaka for Men EDP Spray 100ML (3.4 FL.OZ) B...
# ..                  ...                                                ...
# 995                Avon  Avon Far Away Infinity Eau de Parfum 1.7 fl. o...
# 996             Mancera  Roses Greedy by Mancera perfume for unisex EDP...
# 997           Unbranded  Sweet Tooth Eau de Parfum, Perfume for Women, ...
# 998  Juliette Has A Gun  MMMM BY Juliette Has A Gun perfume for her EDP...
# 999        Paris Hilton  PARIS HILTON ELECTRIFY for Women Cologne 3.4 o...
#
#                type  price priceWithCurrency  available  \
# ...

# %% [markdown]
# # separando as colunas

# %%
url = "dataset/parfum.csv"
pd.read_csv(url,sep=";")
# Out:
#     brand,"title","type","price","priceWithCurrency","available","availableText","sold","lastUpdated","itemLocation"
# 0    Carolina Herrera,"Good Girl by Carolina Herrer...
# 1    As Shown,"Parfums de Marly Delina La Rosee Eau...
# 2    PRADA,"PRADA Paradoxe by Prada EDP 3.0oz/90ml ...
# 3    As Show,"J'adore Parfum D'eau by Christian 3.4...
# 4    Khadlaj,"Shiyaaka for Men EDP Spray 100ML (3.4...
# ..                                                 ...
# 995  Avon,"Avon Far Away Infinity Eau de Parfum 1.7...
# 996  Mancera,"Roses Greedy by Mancera perfume for u...
# 997  Unbranded,"Sweet Tooth Eau de Parfum, Perfume ...
# 998  Juliette Has A Gun,"MMMM BY Juliette Has A Gun...
# 999  Paris Hilton,"PARIS HILTON ELECTRIFY for Women...
#
# [1000 rows x 1 columns]

# %%
dados = pd.read_csv(url,sep=";")
dados
# Out:
#     brand,"title","type","price","priceWithCurrency","available","availableText","sold","lastUpdated","itemLocation"
# 0    Carolina Herrera,"Good Girl by Carolina Herrer...
# 1    As Shown,"Parfums de Marly Delina La Rosee Eau...
# 2    PRADA,"PRADA Paradoxe by Prada EDP 3.0oz/90ml ...
# 3    As Show,"J'adore Parfum D'eau by Christian 3.4...
# 4    Khadlaj,"Shiyaaka for Men EDP Spray 100ML (3.4...
# ..                                                 ...
# 995  Avon,"Avon Far Away Infinity Eau de Parfum 1.7...
# 996  Mancera,"Roses Greedy by Mancera perfume for u...
# 997  Unbranded,"Sweet Tooth Eau de Parfum, Perfume ...
# 998  Juliette Has A Gun,"MMMM BY Juliette Has A Gun...
# 999  Paris Hilton,"PARIS HILTON ELECTRIFY for Women...
#
# [1000 rows x 1 columns]

# %%
dados.head
# Out:
# <bound method NDFrame.head of     brand,"title","type","price","priceWithCurrency","available","availableText","sold","lastUpdated","itemLocation"
# 0    Carolina Herrera,"Good Girl by Carolina Herrer...
# 1    As Shown,"Parfums de Marly Delina La Rosee Eau...
# 2    PRADA,"PRADA Paradoxe by Prada EDP 3.0oz/90ml ...
# 3    As Show,"J'adore Parfum D'eau by Christian 3.4...
# 4    Khadlaj,"Shiyaaka for Men EDP Spray 100ML (3.4...
# ..                                                 ...
# 995  Avon,"Avon Far Away Infinity Eau de Parfum 1.7...
# 996  Mancera,"Roses Greedy by Mancera perfume for u...
# 997  Unbranded,"Sweet Tooth Eau de Parfum, Perfume ...
# 998  Juliette Has A Gun,"MMMM BY Juliette Has A Gun...
# 999  Paris Hilton,"PARIS HILTON ELECTRIFY for Women...
#
# [1000 rows x 1 columns]>
